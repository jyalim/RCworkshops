# %% [markdown]
# # Density-Based Spatial Clustering of Applications with Noise (DBSCAN)
#
# The DBSCAN algorithm is a clustering algorithm that works really well for datasets that have regions of high density.
#
# The model can take array-like objects, either in host as NumPy arrays or in device (as Numba or cuda_array_interface-compliant), as well  as cuDF DataFrames.
#
# For information about the cuDF format, refer to the [cuDF documentation](https://rapidsai.github.io/projects/cudf/en/latest/)
#
# For information about cuML's DBSCAN implementation: https://rapidsai.github.io/projects/cuml/en/latest/api.html#dbscan

# %%
import os

import numpy as np
import cupy as cp

from sklearn import datasets

import pandas as pd
import cudf as gd

from sklearn.datasets import make_blobs

from sklearn.metrics import adjusted_rand_score

from sklearn.cluster import DBSCAN as skDBSCAN
from cuml.cluster import DBSCAN as cumlDBSCAN
cp.cuda.Device(2).use()

# %% [markdown]
# ## Define Parameters

# %%
n_samples = 100000
n_features = 128

eps = 3
min_samples = 2

# %% [markdown]
# ## Generate Data
#
# ### Host

# %%
host_data, host_labels = make_blobs(
   n_samples=n_samples, n_features=n_features, centers=5, random_state=7)

host_data = pd.DataFrame(host_data)
host_labels = pd.Series(host_labels)

# %% [markdown]
# ### Device

# %%
device_data = gd.DataFrame.from_pandas(host_data)
device_labels = gd.Series(host_labels)

# %% [markdown]
# ## Scikit-learn Model

# %%
# %%time
clustering_sk = skDBSCAN(eps=eps,
                         min_samples=min_samples,
                         algorithm="brute",
                         n_jobs=-1)
clustering_sk.fit(host_data)
# Out:
# Exception in thread QueueManagerThread:
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py", line 747, in _queue_management_worker
#     recursive_terminate(p)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/backend/utils.py", line 28, in recursive_terminate
#     _recursive_terminate_without_psutil(process)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/backend/utils.py", line 53, in _recursive_terminate_without_psutil
#     _recursive_terminate(process.pid)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/backend/utils.py", line 94, in _recursive_terminate
#     stderr=None
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/subprocess.py", line 336, in check_output
#     **kwargs).stdout
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/subprocess.py", line 418, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['pgrep', '-P', '32336']' died with <Signals.SIGINT: 2>.
#
# ERROR:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 833, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 521, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/concurrent/futures/_base.py", line 427, in result
#     self._condition.wait(timeout)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py", line 295, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/magics/execution.py", line 1238, in time
#     exec(code, glob, local_ns)
#   File "<timed exec>", line 5, in <module>
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/cluster/dbscan_.py", line 321, in fit
#     **self.get_params())
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/cluster/dbscan_.py", line 161, in dbscan
#     return_distance=False)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/neighbors/base.py", line 726, in radius_neighbors
#     neigh_ind_list = sum(results, [])
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/metrics/pairwise.py", line 1302, in pairwise_distances_chunked
#     n_jobs=n_jobs, **kwds)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/daal4py/sklearn/monkeypatch/pairwise.py", line 180, in daal_pairwise_distances
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/metrics/pairwise.py", line 1073, in _parallel_pairwise
#     for s in gen_even_slices(_num_samples(Y), effective_n_jobs(n_jobs)))
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 930, in __call__
#     self.retrieve()
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 855, in retrieve
#     backend.abort_everything(ensure_ready=ensure_ready)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 538, in abort_everything
#     self._workers.shutdown(kill_workers=True)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py", line 1096, in shutdown
#     qmt.join()
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 1488, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 1446, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 833, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 521, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/concurrent/futures/_base.py", line 427, in result
#     self._condition.wait(timeout)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py", line 295, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/magics/execution.py", line 1238, in time
#     exec(code, glob, local_ns)
#   File "<timed exec>", line 5, in <module>
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/cluster/dbscan_.py", line 321, in fit
#     **self.get_params())
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/cluster/dbscan_.py", line 161, in dbscan
#     return_distance=False)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/neighbors/base.py", line 726, in radius_neighbors
#     neigh_ind_list = sum(results, [])
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/metrics/pairwise.py", line 1302, in pairwise_distances_chunked
#     n_jobs=n_jobs, **kwds)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/daal4py/sklearn/monkeypatch/pairwise.py", line 180, in daal_pairwise_distances
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/metrics/pairwise.py", line 1073, in _parallel_pairwise
#     for s in gen_even_slices(_num_samples(Y), effective_n_jobs(n_jobs)))
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 930, in __call__
#     self.retrieve()
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 855, in retrieve
#     backend.abort_everything(ensure_ready=ensure_ready)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 538, in abort_everything
#     self._workers.shutdown(kill_workers=True)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py", line 1096, in shutdown
#     qmt.join()
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-e151521c23c4>", line 1, in <module>
#     get_ipython().run_cell_magic('time', '', 'clustering_sk = skDBSCAN(eps=eps,\n                         min_samples=min_samples,\n                         algorithm="brute",\n                         n_jobs=-1)\nclustering_sk.fit(host_data)')
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2167, in run_cell_magic
#     result = fn(magic_arg_s, cell)
#   File "<decorator-gen-62>", line 2, in time
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/magics/execution.py", line 1240, in time
#     self.shell.showtraceback()
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1866, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1373, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1281, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1144, in structured_traceback
#     formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
# TypeError: must be str, not list
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 1488, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 1446, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ERROR:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 833, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 521, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/concurrent/futures/_base.py", line 427, in result
#     self._condition.wait(timeout)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py", line 295, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/magics/execution.py", line 1238, in time
#     exec(code, glob, local_ns)
#   File "<timed exec>", line 5, in <module>
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/cluster/dbscan_.py", line 321, in fit
#     **self.get_params())
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/cluster/dbscan_.py", line 161, in dbscan
#     return_distance=False)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/neighbors/base.py", line 726, in radius_neighbors
#     neigh_ind_list = sum(results, [])
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/metrics/pairwise.py", line 1302, in pairwise_distances_chunked
#     n_jobs=n_jobs, **kwds)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/daal4py/sklearn/monkeypatch/pairwise.py", line 180, in daal_pairwise_distances
#     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/metrics/pairwise.py", line 1073, in _parallel_pairwise
#     for s in gen_even_slices(_num_samples(Y), effective_n_jobs(n_jobs)))
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 930, in __call__
#     self.retrieve()
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 855, in retrieve
#     backend.abort_everything(ensure_ready=ensure_ready)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 538, in abort_everything
#     self._workers.shutdown(kill_workers=True)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py", line 1096, in shutdown
#     qmt.join()
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-e151521c23c4>", line 1, in <module>
#     get_ipython().run_cell_magic('time', '', 'clustering_sk = skDBSCAN(eps=eps,\n                         min_samples=min_samples,\n                         algorithm="brute",\n                         n_jobs=-1)\nclustering_sk.fit(host_data)')
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2167, in run_cell_magic
#     result = fn(magic_arg_s, cell)
#   File "<decorator-gen-62>", line 2, in time
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/magics/execution.py", line 1240, in time
#     self.shell.showtraceback()
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1866, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1373, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1281, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1144, in structured_traceback
#     formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
# TypeError: must be str, not list
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2909, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2980, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1866, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1373, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1281, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1144, in structured_traceback
#     formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
# TypeError: must be str, not list
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 1488, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 1446, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/posixpath.py", line 389, in realpath
#     return abspath(path)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/posixpath.py", line 378, in abspath
#     return normpath(path)
#   File "/home/jyalim/.local/opt/anaconda/envs/rapids/lib/python3.6/posixpath.py", line 350, in normpath
#     path.startswith(sep*2) and not path.startswith(sep*3)):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     426
# --> 427             self._condition.wait(timeout)
#     428
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py in wait(self, timeout)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1237             try:
# -> 1238                 exec(code, glob, local_ns)
#    1239             except:
#
# <timed exec> in <module>()
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/cluster/dbscan_.py in fit(self, X, y, sample_weight)
#     320         clust = dbscan(X, sample_weight=sample_weight,
# --> 321                        **self.get_params())
#     322         self.core_sample_indices_, self.labels_ = clust
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/cluster/dbscan_.py in dbscan(X, eps, min_samples, metric, metric_params, algorithm, leaf_size, p, sample_weight, n_jobs)
#     160         neighborhoods = neighbors_model.radius_neighbors(X, eps,
# --> 161                                                          return_distance=False)
#     162
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/neighbors/base.py in radius_neighbors(self, X, radius, return_distance)
#     725             else:
# --> 726                 neigh_ind_list = sum(results, [])
#     727                 results = np.empty(len(neigh_ind_list), dtype='object')
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1301         D_chunk = pairwise_distances(X_chunk, Y, metric=metric,
# -> 1302                                      n_jobs=n_jobs, **kwds)
#    1303         if ((X is Y or Y is None)
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/daal4py/sklearn/monkeypatch/pairwise.py in daal_pairwise_distances(X, Y, metric, n_jobs, **kwds)
#     179
# --> 180     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1072         fd(X, Y[s], **kwds)
# -> 1073         for s in gen_even_slices(_num_samples(Y), effective_n_jobs(n_jobs)))
#    1074
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     854                     ensure_ready = self._managed_backend
# --> 855                     backend.abort_everything(ensure_ready=ensure_ready)
#     856
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in abort_everything(self, ensure_ready)
#     537         """
# --> 538         self._workers.shutdown(kill_workers=True)
#     539         delete_folder(self._workers._temp_folder)
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py in shutdown(self, wait, kill_workers)
#    1095             if wait:
# -> 1096                 qmt.join()
#    1097
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py in join(self, timeout)
#    1055         if timeout is None:
# -> 1056             self._wait_for_tstate_lock()
#    1057         else:
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1071             assert self._is_stopped
# -> 1072         elif lock.acquire(block, timeout):
#    1073             lock.release()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1862                         # in the engines. This should return a list of strings.
# -> 1863                         stb = value._render_traceback_()
#    1864                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1862                         # in the engines. This should return a list of strings.
# -> 1863                         stb = value._render_traceback_()
#    1864                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2978             if result is not None:
#    2979                 result.error_in_exec = sys.exc_info()[1]
# -> 2980             self.showtraceback(running_compiled_code=True)
#    2981         else:
#    2982             outflag = False
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1864                     except Exception:
#    1865                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 1866                                             value, tb, tb_offset=tb_offset)
#    1867
#    1868                     self._showtraceback(etype, value, stb)
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1371         self.tb = tb
#    1372         return FormattedTB.structured_traceback(
# -> 1373             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1374
#    1375
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1279             # Verbose modes need a full traceback
#    1280             return VerboseTB.structured_traceback(
# -> 1281                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1282             )
#    1283         else:
#
# ~/.local/opt/anaconda/envs/rapids/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1142         exception = self.get_parts_of_chained_exception(evalue)
#    1143         if exception:
# -> 1144             formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
#    1145             etype, evalue, etb = exception
#    1146         else:
#
# TypeError: must be str, not list

# %% [markdown]
# ## cuML Model

# %%
# %%time
clustering_cuml = cumlDBSCAN(eps=eps,
                             min_samples=min_samples)
clustering_cuml.fit(device_data)
# Out:
# CPU times: user 11.9 s, sys: 6.37 s, total: 18.3 s
# Wall time: 18.5 s

# %% [markdown]
# ## Evaluate Results

# %%
# %%time
cuml_score = adjusted_rand_score(host_labels, clustering_cuml.labels_)
sk_score = adjusted_rand_score(host_labels, clustering_sk.labels_)
