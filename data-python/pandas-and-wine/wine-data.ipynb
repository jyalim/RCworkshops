# %% [markdown]
# Exploring Wine Data
# ===

# %%
import pandas as pd
import numpy as np
import pylab as plt
import seaborn as sns
from plt_style import *
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('dat/winequality-red.csv',delimiter=';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
(df.std() / df.mean()).sort_values()
# Out:
# density                 0.001893
# pH                      0.046627
# alcohol                 0.102242
# quality                 0.143287
# fixed acidity           0.209276
# sulphates               0.257551
# volatile acidity        0.339244
# chlorides               0.538095
# residual sugar          0.555351
# free sulfur dioxide     0.658911
# total sulfur dioxide    0.707917
# citric acid             0.718888
# dtype: float64

# %%
_ = sns.pairplot(df,vars=['citric acid','total sulfur dioxide','density','quality'],hue='quality',palette='husl')

# %%
df.groupby('quality').nunique()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                    9                10            6               8
# 4                   37                45           29              23
# 5                   76               118           71              65
# 6                   85               102           72              50
# 7                   62                54           58              48
# 8                   15                15           17              13
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density  pH  \
# quality
# 3               10                    7                     9       10  10
# 4               36                   22                    36       48  37
# 5              114                   51                   137      239  76
# 6              102                   50                    99      266  80
# 7               67                   36                    61      122  54
# 8               17                   12                    13       17  13
#
#          sulphates  alcohol
# quality
# 3                9       10
# 4               29       25
# 5               78       42
# 6               69       56
# 7               51       42
# 8               11       15

# %%
sns.swarmplot(x='quality', y='citric acid',data=df,palette='husl')
# Out:
# /tmp/ipykernel_3007478/3959276020.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='quality', y='citric acid',data=df,palette='husl')
# /packages/envs/scicomp/lib/python3.11/site-packages/seaborn/categorical.py:3543: UserWarning: 56.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /packages/envs/scicomp/lib/python3.11/site-packages/seaborn/categorical.py:3543: UserWarning: 52.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /packages/envs/scicomp/lib/python3.11/site-packages/seaborn/categorical.py:3543: UserWarning: 13.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='quality', ylabel='citric acid'>
# /packages/envs/scicomp/lib/python3.11/site-packages/seaborn/categorical.py:3543: UserWarning: 59.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /packages/envs/scicomp/lib/python3.11/site-packages/seaborn/categorical.py:3543: UserWarning: 56.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /packages/envs/scicomp/lib/python3.11/site-packages/seaborn/categorical.py:3543: UserWarning: 17.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x='quality', y='citric acid',data=df,palette='husl',inner=None)
# Out:
# <AxesSubplot: xlabel='quality', ylabel='citric acid'>

# %%
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
pio.renderers.default = 'iframe'

# %%
fig=px.scatter_3d(
    df,
    x='citric acid',
    y='density',
    z='quality',
    color='quality',
    color_continuous_scale='viridis',
)
fig.update_traces(
    marker=dict(
        opacity=0.4,
        size=10,
        line=dict(
            width=0,
            color='black',
        ),
    ),
    selector=dict(mode='markers'),
)

fig.update_layout(
    width=1000,
    height=800,
    hoverlabel=dict(
        font=dict(
            family='monospace',
            size=10,
        ),
    ),
    legend_font=dict(color='#eee',size=24),
    legend_itemsizing='constant',
    legend_bgcolor='#444',
    paper_bgcolor='#222',
    plot_bgcolor='#333',
    scene = dict(
        xaxis = dict(
             backgroundcolor="#555",
             gridcolor="#111",
             showbackground=True,
             zerolinecolor="#111",),
        yaxis = dict(
            backgroundcolor="#333",
            gridcolor="#111",
            showbackground=True,
            zerolinecolor="#111"),
        zaxis = dict(
            backgroundcolor="rgba(0,0,0,0)",
            gridcolor="#111",
            showbackground=True,
            zerolinecolor="#111",
        ),
    ),
    font_color="#111",
)


fig.update_layout(paper_bgcolor="#ddd")
# Out:
# <iframe
#     scrolling="no"
#     width="1020px"
#     height="820"
#     src="iframe_figures/figure_18.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = px.colors.sequential.swatches_continuous()
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="520px"
#     height="2660"
#     src="iframe_figures/figure_19.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
